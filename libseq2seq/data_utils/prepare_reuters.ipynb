# %%
import os
import numpy as np
from tqdm import tqdm

DATA_DIR = '../../datasets/reuters'
train_folder = os.path.join(DATA_DIR, 'training')
test_folder = os.path.join(DATA_DIR, 'test')

# %%
def get_docs(folder):
    files = np.array(os.listdir(folder))
    files = files[np.argsort(np.array(files, dtype=int))]
    docs = []
    ids = []
    for filename in tqdm(files):
        filepath = os.path.join(folder, filename)
        try:
            doc = open(filepath, 'r', encoding='utf-8')
            docs.append(doc.read())
            ids.append(filename)
        except UnicodeDecodeError:
            doc.close()
    return docs, ids

# %%
train_docs, train_ids = get_docs(train_folder)
test_docs, test_ids = get_docs(test_folder)
# Out:
# 100%|██████████| 7769/7769 [00:00<00:00, 20624.80it/s]
# 100%|██████████| 3019/3019 [00:00<00:00, 25722.26it/s]

# %%
len(test_docs)
# Out:
# 3018

# %%
len(train_docs)
# Out:
# 7769

# %%
classes = open(os.path.join(DATA_DIR, 'cats.txt'), 'r', encoding='utf-8')

# %%
class_lines = classes.readlines()

# %%
labels_set = set()

# %%
train_labels_dict = {}
test_labels_dict = {}

for line in class_lines:
    labels_split = line.strip().split()
    split_type, doc_id = labels_split[0].split('/')
    labels = labels_split[1:]
    labels_set |= set(labels)
    #print(split_type, doc_id, labels)
    if split_type == 'test':
        test_labels_dict[doc_id] = labels
    else:
        train_labels_dict[doc_id] = labels

# %%
train_labels = []
for doc_id in train_ids:
    train_labels.append(train_labels_dict[doc_id])
test_labels = []
for doc_id in test_ids:
    test_labels.append(test_labels_dict[doc_id])

# %%
np.mean([len(train_labels[i]) for i in range(len(train_labels))])
# Out:
# 1.2337495173123953

# %%
label_names = np.array(list(labels_set))
label_to_index = dict(zip(label_names, np.arange(len(label_names))))

# %%
frequences = [0] * len(label_to_index)
for ind in range(len(train_labels)):
    for label_index in train_labels[ind]:
        frequences[label_to_index[label_index]] += 1
        
index_to_frequency_index = dict(zip(np.argsort(frequences)[::-1],
                                    np.arange(len(frequences))))
frequency_indexes = [index_to_frequency_index[label_to_index[label]]
                     for label in label_names]
label_to_index = dict(zip(label_names, frequency_indexes))
index_to_label = dict(zip(frequency_indexes, label_names))

labels_train = []
for labels in train_labels:
    labels_train.append(sorted(
        [label_to_index[label] for label in labels]))
    
labels_test = []
for labels in test_labels:
    labels_test.append(sorted(
        [label_to_index[label] for label in labels]))

# %%
import pandas as pd

# %%
df_train_valid = pd.DataFrame({
    'text': train_docs,
    'id': train_ids,
    'labels': labels_train
})

df_test = pd.DataFrame({
    'text': test_docs,
    'id': test_ids,
    'labels': labels_test
})

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_valid = train_test_split(df_train_valid, test_size=0.1,
                                      random_state=3773)

# %%
df_train_valid.head()
# Out:
#                                                 text  id  \
# 0  BAHIA COCOA REVIEW\n  Showers continued throug...   1
# 1  NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESER...   5
# 2  ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS\...   6
# 3  CHAMPION PRODUCTS &lt;CH> APPROVES STOCK SPLIT...   9
# 4  COMPUTER TERMINAL SYSTEMS &lt;CPML> COMPLETES ...  10
#
#                                       labels
# 0                                       [23]
# 1                      [3, 7, 9, 32, 39, 62]
# 2  [3, 7, 9, 13, 17, 18, 39, 53, 57, 67, 84]
# 3                                        [0]
# 4                                        [1]

# %%
df_test.head()
# Out:
#                                                 text     id  \
# 0  ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RI...  14826
# 1  CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STO...  14828
# 2  JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWA...  14829
# 3  THAI TRADE DEFICIT WIDENS IN FIRST QUARTER\n  ...  14832
# 4  INDONESIA SEES CPO PRICE RISING SHARPLY\n  Ind...  14833
#
#                       labels
# 0                        [5]
# 1                        [3]
# 2                    [4, 21]
# 3  [3, 5, 9, 12, 34, 36, 46]
# 4                   [17, 37]

# %%
len(df_train_valid), len(df_train),len(df_valid), len(df_test)
# Out:
# (7769, 6992, 777, 3018)

# %%
df_train.to_csv(os.path.join(DATA_DIR, 'train.csv'),
                encoding='utf-8', index=0)
df_valid.to_csv(os.path.join(DATA_DIR, 'valid.csv'),
                encoding='utf-8', index=0)
df_test.to_csv(os.path.join(DATA_DIR, 'test.csv'),
               encoding='utf-8', index=0)

# %%
df_train
# Out:
#                                                    text     id  \
# 7124  &lt;OCELOT INDUSTRIES LTD> YEAR LOSS\n  Shr lo...  12391
# 4953  JAPAN ECONOMY MAY START BOTTOMING OUT SOON -AG...   8671
# 2105  PLACER &lt;PLC> TO INCREASE STAKE IN EQUITY SI...   3868
# 5225  Sumita says major nations cooperated to stabil...   9132
# 900   UNICORP AMERICAN CORP &lt;UAC> 4TH QTR NET\n  ...   1722
# 3396  &lt;CABRE EXPLORATION LTD> SIX MTHS JAN 31 NET...   6055
# 3985  JOHN FAIRFAX LTD &lt;FFXA.S> FIRST HALF\n  26 ...   6999
# 7484  CULLEN/FROST &lt;CFBI> TO OMIT DIVIDEND\n  Cul...  13180
# 2270  LEIGH-PEMBERTON OPPOSES TAKEOVER PROTECTION RU...   4127
# 6808  U.S. CREDIT MARKET OUTLOOK - PRIME RATE\n  The...  11861
# 3603  DIXONS HAS 56 PCT OF CYCLOPS CORP\n  Dixons Gr...   6402
# 6829  ENERGY DEVELOPMENT &lt;EDP> COMPLETES MAY &lt;...  11892
# 3824  DEL-VAL FINANCIAL CORP &lt;DVL> SETS PAYOUT\n ...   6733
# 2975  DECORATOR INDUSTRIES INC &lt;DII> 4TH QTR NET\...   5354
# 6504  U.S. SENATE LEADERS SEE NO TRADE WAR BREWING\n...  11357
# 5143  HAYES-ALBION &lt;HAY> COMPLETES GOING PRIVATE ...   8998
# 4495  ATT &lt;T> CHAIRMAN SAYS DIVIDEND WILL NOT BE ...   7876
# 6037  WESTINGHOUSE INTERESTED IN MERGER OF RADIO UNI...  10555
# 1384  TREASURY'S BAKER FORECASTS REDUCTION IN JAPANE...   2622
# 3546  API SAYS DISTILLATE, GAS STOCKS OFF IN WEEK\n ...   6301
# 4954  KUWAIT SAYS OPEC 2.4 MLN BPD BELOW CEILING\n  ...   8672
# 2452  PARKER DRILLING SUSPENDS QUARTERLY DIVIDEND\n\...   4433
# 7239  EC MUST EXPLAIN FARM POLICY TO U.S., FRANCE SA...  12564
# 1859  USSR SEEN LIKELY TO HONOR CORN COMMITMENT\n  T...   3429
# 714   FLORIDA COMMERCIAL BANKS INC &lt;FLBK> DIVIDEN...   1363
# 1631  ECUADOR TO EXPORT NO OIL FOR 4 MONTHS, OFFICIA...   3048
# 4606  MINORCO &lt;MNRCY> HALF YEAR DEC 31\n  Shr 26 ...   8048
# 2957  BRAZILIAN BANK WORKERS DECIDE ON NATIONAL STRI...   5330
# 594   CHILEAN CONSUMER PRICES RISE 1.7 PCT IN FEBRUA...   1147
# 3761  U.S. HOUSE PLAN SEEKS TO BAR FOREIGN TAKEOVERS...   6639
# ...                                                 ...    ...
# 7620  BUNDESBANK RETAINS MONEY SUPPLY POLICY\n  Bund...  13949
# 3659  NFS FINANCIAL &lt;NFSF> SETS INITIAL DIVIDEND\...   6478
# 2453  FIRST GRANITE BANCORP INC AGREES TO BE ACQUIRE...   4434
# 5328  CCC ACCEPTS BONUS BID ON CATTLE FOR EGYPT - US...   9290
# 5181  MARYLAND NATIONAL &lt;MDNT> SEES NEW NAME\n  M...   9064
# 427   ITT'S &lt;ITT> HARTFORD UNIT POSTS 4TH QTR GAI...    852
# 3930  RESULTS AWAITED ON EGYPT PL 480 WHEAT TENDER\n...   6898
# 1233  HOMESTEAD FINANCIAL &lt;HFL> UPS CASH DIVIDEND...   2379
# 6690  U.S. SENATE PASSES HOUSING BILL\n  The Senate ...  11665
# 1368  U.K. OFFICIALS STUDY SALMONELLA/CALF FEED LINK...   2594
# 3977   German net currency reserves fall 5.4 billion...   6983
# 2903  UK FEB RETAIL SALES RISE PROVISIONAL 2.2 PCT (...   5254
# 4801  ASTROCOM CORP &lt;ACOM> 4TH QTR NET\n  Shr one...   8407
# 7570  BRITAIN WARNS JAPAN OVER TRADE ROW\n  British ...  13649
# 6757  COMMERZBANK SEES LOWER OPERATING PROFIT THIS Y...  11773
# 5139  USDA REPORTS CORN SWITCHED TO USSR\n  The U.S....   8993
# 3131  AMCAST INDUSTRIAL CORP &lt;ACST> 2ND QTR MARCH...   5600
# 6730  STANDARD OIL RAISES ALASKA NORTH SLOPE BY 1.50...  11731
# 6438   BRITISH CALEDONIAN GROUP ANNOUNCES BIG LOSSES...  11249
# 2756  PLM &lt;PLMA> UNIT ENDS MERGER TALKS\n  PLM Co...   5001
# 429   CBT FEBRUARY VOLUME DOWN 14 PCT FROM YEAR AGO\...    855
# 3821  CAROLINA POWER AND LIGHT CO &lt;CPL> SETS PAYO...   6730
# 122   RELIEF TO U.S. CORN/OATS GROWERS SAID LIKELY\n...    197
# 5856  &lt;MARATHON NATIONAL BANK> YEAR NET\n  Shr 78...  10235
# 5535  LATIN OIL PRODUCERS TO MEET IN CARACAS\n  Five...   9674
# 6779  H.K. BANKS TO RAISE PRIME RATES SOON, DEALERS ...  11817
# 6393  CSR SELLING DELHI TO EXXON UNIT, DROPS DELHI F...  11177
# 897   LIBERTY FINANCIAL GROUP &lt;LFG> REGULAR DIVID...   1716
# 1706  HUDSON BAY MINING CUTS U.S., CANADA ZINC PRICE...   3163
# 5477  MEDAR &lt;MDXR> CHANGES FISCAL YEAR\n  Medar I...   9563
#
#                   labels
# 7124                 [0]
# 4953             [5, 29]
# 2105             [1, 42]
# 5225                 [2]
# 900                  [0]
# 3396                 [0]
# 3985                 [0]
# 7484                 [0]
# 2270                 [1]
# 6808                 [6]
# 3603                 [1]
# 6829                 [1]
# 3824                 [0]
# 2975                 [0]
# 6504                 [5]
# 5143                 [1]
# 4495                 [0]
# 6037                 [1]
# 1384                 [5]
# 3546                 [4]
# 4954                 [4]
# 2452                 [0]
# 7239                 [5]
# 1859           [3, 7, 9]
# 714                  [0]
# 1631                 [4]
# 4606                 [0]
# 2957                 [8]
# 594                 [22]
# 3761                 [1]
# ...                  ...
# 7620             [2, 10]
# 3659                 [0]
# 2453                 [1]
# 5328                [20]
# 5181                 [1]
# 427                  [0]
# 3930              [3, 7]
# 1233                 [0]
# 6690                [48]
# 1368                [20]
# 3977                [24]
# 2903                [40]
# 4801                 [0]
# 7570                 [5]
# 6757                 [0]
# 5139           [3, 7, 9]
# 3131                 [0]
# 6730                 [4]
# 6438                 [0]
# 2756                 [1]
# 429   [3, 9, 13, 18, 62]
# 3821                 [0]
# 122           [3, 9, 62]
# 5856                 [0]
# 5535                 [4]
# 6779                 [6]
# 6393                 [1]
# 897                  [0]
# 1706                [41]
# 5477                 [0]
#
# [6992 rows x 3 columns]

# %%
doc_lengths = [len(train_docs[i].split()) for i in range(len(train_docs))]
np.mean(doc_lengths), np.std(doc_lengths)
# Out:
# (130.11185480756853, 137.5386571049968)

# %%
130 + 137
# Out:
# 267

# %%
labels_train[:10]
# Out:
# [[23],
#  [3, 7, 9, 32, 39, 62],
#  [3, 7, 9, 13, 17, 18, 39, 53, 57, 67, 84],
#  [0],
#  [1],
#  [0],
#  [0, 1],
#  [0],
#  [0],
#  [0]]

# %%
label_to_index
# Out:
# {'ship': 10}

# %%
label_names
# Out:
# ['money-supply',
#  'lei',
#  'veg-oil',
#  'dlr',
#  'cotton',
#  'oilseed',
#  'bop',
#  'iron-steel',
#  'cpu',
#  'strategic-metal',
#  'lin-oil',
#  'cpi',
#  'ipi',
#  'oat',
#  'gnp',
#  'castor-oil',
#  'income',
#  'earn',
#  'l-cattle',
#  'jet',
#  'livestock',
#  'tea',
#  'coconut',
#  'palladium',
#  'palm-oil',
#  'cotton-oil',
#  'barley',
#  'silver',
#  'propane',
#  'housing',
#  'nkr',
#  'palmkernel',
#  'acq',
#  'cocoa',
#  'soy-oil',
#  'platinum',
#  'wpi',
#  'pet-chem',
#  'rand',
#  'gold',
#  'reserves',
#  'corn',
#  'nzdlr',
#  'rice',
#  'carcass',
#  'groundnut-oil',
#  'nat-gas',
#  'jobs',
#  'heat',
#  'naphtha',
#  'grain',
#  'trade',
#  'dfl',
#  'lumber',
#  'sun-oil',
#  'coffee',
#  'hog',
#  'soy-meal',
#  'orange',
#  'yen',
#  'instal-debt',
#  'nickel',
#  'crude',
#  'interest',
#  'gas',
#  'sorghum',
#  'copra-cake',
#  'potato',
#  'sugar',
#  'rape-oil',
#  'zinc',
#  'sunseed',
#  'dmk',
#  'fuel',
#  'wheat',
#  'soybean',
#  'retail',
#  'rubber',
#  'copper',
#  'tin',
#  'ship',
#  'meal-feed',
#  'sun-meal',
#  'alum',
#  'groundnut',
#  'lead',
#  'rye',
#  'coconut-oil',
#  'rapeseed',
#  'money-fx']

# %%
train_labels_dict
# Out:
# {'1': ['cocoa'],
#  '5': ['sorghum', 'oat', 'barley', 'corn', 'wheat', 'grain'],
#  '6': ['wheat',
#   'sorghum',
#   'grain',
#   'sunseed',
#   'corn',
#   'oilseed',
#   'soybean',
#   'sun-oil',
#   'soy-oil',
#   'lin-oil',
#   'veg-oil'],
#  '9': ['earn'],
#  '10': ['acq'],
#  '11': ['earn'],
#  '12': ['acq', 'earn'],
#  '13': ['earn'],
#  '14': ['earn'],
#  '18': ['earn'],
#  '19': ['grain', 'wheat'],
#  '22': ['copper'],
#  '23': ['earn'],
#  '24': ['earn'],
#  '27': ['earn'],
#  '29': ['housing'],
#  '30': ['money-supply'],
#  '36': ['earn'],
#  '37': ['earn'],
#  '38': ['earn'],
#  '40': ['earn'],
#  '41': ['earn'],
#  '42': ['coffee'],
#  '44': ['ship', 'acq'],
#  '45': ['acq'],
#  '46': ['sugar'],
#  '47': ['trade'],
#  '48': ['reserves'],
#  '49': ['ship'],
#  '50': ['earn'],
#  '53': ['earn'],
#  '56': ['earn'],
#  '57': ['corn', 'grain'],
#  '58': ['money-supply'],
#  '59': ['ship'],
#  '64': ['earn'],
#  '65': ['earn'],
#  '66': ['earn'],
#  '68': ['acq'],
#  '69': ['soy-meal', 'meal-feed', 'oilseed', 'soybean', 'veg-oil'],
#  '71': ['earn'],
#  '74': ['earn'],
#  '75': ['coffee'],
#  '76': ['money-supply'],
#  '77': ['money-supply'],
#  '78': ['money-supply'],
#  '80': ['money-supply'],
#  '81': ['money-supply'],
#  '82': ['earn'],
#  '83': ['earn'],
#  '85': ['earn'],
#  '86': ['earn'],
#  '87': ['earn'],
#  '89': ['earn'],
#  '92': ['money-supply'],
#  '93': ['earn'],
#  '94': ['money-supply'],
#  '95': ['money-supply'],
#  '96': ['acq'],
#  '97': ['oilseed',
#   'soybean',
#   'sorghum',
#   'rye',
#   'oat',
#   'corn',
#   'wheat',
#   'grain'],
#  '98': ['earn'],
#  '99': ['money-supply'],
#  '100': ['money-supply'],
#  '101': ['money-supply'],
#  '102': ['money-supply'],
#  '103': ['money-supply'],
#  '104': ['cotton'],
#  '105': ['sugar'],
#  '106': ['ship', 'grain'],
#  '108': ['earn'],
#  '109': ['money-supply'],
#  '110': ['acq'],
#  '111': ['money-supply'],
#  '113': ['earn'],
#  '121': ['livestock', 'carcass'],
#  '123': ['earn'],
#  '124': ['grain'],
#  '125': ['acq'],
#  '126': ['earn'],
#  '127': ['crude'],
#  '128': ['acq'],
#  '129': ['earn'],
#  '130': ['earn'],
#  '132': ['money-supply'],
#  '133': ['money-supply'],
#  '134': ['acq'],
#  '135': ['acq'],
#  '136': ['grain'],
#  '138': ['earn'],
#  '139': ['earn'],
#  '140': ['earn'],
#  '142': ['earn'],
#  '143': ['earn'],
#  '144': ['crude'],
#  '145': ['earn'],
#  '146': ['earn'],
#  '147': ['earn'],
#  '151': ['earn'],
#  '152': ['earn'],
#  '153': ['acq'],
#  '157': ['acq'],
#  '160': ['earn'],
#  '162': ['acq'],
#  '163': ['earn'],
#  '164': ['earn'],
#  '165': ['earn'],
#  '166': ['earn'],
#  '167': ['earn'],
#  '168': ['earn'],
#  '169': ['earn'],
#  '176': ['nat-gas'],
#  '179': ['gnp', 'cpi'],
#  '180': ['wheat', 'grain'],
#  '183': ['earn'],
#  '185': ['acq'],
#  '186': ['acq'],
#  '187': ['earn'],
#  '189': ['crude'],
#  '191': ['crude'],
#  '193': ['corn', 'grain'],
#  '194': ['crude'],
#  '196': ['earn'],
#  '197': ['oat', 'corn', 'grain'],
#  '198': ['money-supply'],
#  '199': ['acq'],
#  '200': ['soy-meal', 'soy-oil', 'soybean', 'meal-feed', 'oilseed', 'veg-oil'],
#  '201': ['earn'],
#  '202': ['earn'],
#  '203': ['money-supply'],
#  '209': ['gnp', 'cpi'],
#  '210': ['earn'],
#  '211': ['crude'],
#  '212': ['earn'],
#  '213': ['cpi'],
#  '214': ['earn'],
#  '216': ['money-supply'],
#  '220': ['money-supply'],
#  '221': ['interest', 'money-fx'],
#  '225': ['interest'],
#  '227': ['bop', 'gnp'],
#  '228': ['rice', 'grain'],
#  '229': ['oilseed', 'soybean'],
#  '232': ['coffee'],
#  '233': ['interest'],
#  '235': ['cotton',
#   'soy-meal',
#   'tea',
#   'coffee',
#   'palmkernel',
#   'palm-oil',
#   'corn',
#   'copra-cake',
#   'rubber',
#   'sugar',
#   'soybean',
#   'veg-oil',
#   'rice',
#   'wheat',
#   'grain'],
#  '236': ['crude'],
#  '237': ['crude'],
#  '241': ['wheat', 'grain'],
#  '242': ['crude'],
#  '246': ['crude'],
#  '247': ['money-fx'],
#  '248': ['crude'],
#  '249': ['coffee'],
#  '253': ['wheat', 'grain'],
#  '254': ['wheat', 'grain'],
#  '256': ['money-fx'],
#  '259': ['sugar'],
#  '260': ['acq'],
#  '267': ['copra-cake', 'meal-feed'],
#  '271': ['trade'],
#  '272': ['alum'],
#  '273': ['crude'],
#  '274': ['palm-oil', 'veg-oil'],
#  '275': ['coffee', 'cocoa', 'tea'],
#  '279': ['earn'],
#  '281': ['ship'],
#  '283': ['reserves'],
#  '284': ['reserves'],
#  '290': ['coffee'],
#  '293': ['sugar'],
#  '296': ['interest', 'money-fx'],
#  '297': ['soybean', 'oilseed'],
#  '298': ['acq'],
#  '299': ['earn'],
#  '302': ['acq'],
#  '303': ['soy-meal', 'meal-feed', 'soybean', 'oilseed'],
#  '304': ['acq'],
#  '307': ['interest', 'money-fx'],
#  '309': ['strategic-metal', 'platinum', 'gold'],
#  '310': ['meal-feed'],
#  '311': ['tin'],
#  '312': ['bop', 'trade'],
#  '313': ['groundnut-oil',
#   'palm-oil',
#   'soy-oil',
#   'veg-oil',
#   'rapeseed',
#   'soybean',
#   'sunseed',
#   'oilseed'],
#  '314': ['gold'],
#  '315': ['acq'],
#  '317': ['earn'],
#  '320': ['palm-oil', 'rape-oil', 'veg-oil'],
#  '322': ['interest'],
#  '323': ['reserves'],
#  '327': ['rapeseed', 'oilseed', 'corn', 'grain', 'soy-meal', 'meal-feed'],
#  '330': ['money-supply'],
#  '331': ['acq'],
#  '332': ['palm-oil', 'veg-oil'],
#  '334': ['acq'],
#  '336': ['interest', 'money-fx'],
#  '338': ['trade'],
#  '341': ['interest', 'money-fx'],
#  '342': ['trade'],
#  '343': ['sugar'],
#  '345': ['earn'],
#  '346': ['strategic-metal'],
#  '349': ['crude'],
#  '352': ['crude'],
#  '353': ['crude'],
#  '354': ['trade'],
#  '356': ['earn'],
#  '361': ['acq'],
#  '362': ['acq'],
#  '366': ['acq'],
#  '368': ['ship', 'crude'],
#  '369': ['acq'],
#  '371': ['acq'],
#  '372': ['acq'],
#  '374': ['cotton'],
#  '376': ['acq'],
#  '377': ['alum'],
#  '378': ['earn'],
#  '379': ['acq'],
#  '381': ['earn'],
#  '383': ['acq'],
#  '387': ['acq'],
#  '388': ['earn'],
#  '389': ['acq'],
#  '390': ['earn'],
#  '392': ['earn'],
#  '393': ['acq'],
#  '395': ['barley', 'corn', 'wheat', 'grain'],
#  '396': ['earn'],
#  '398': ['acq'],
#  '399': ['earn'],
#  '400': ['acq'],
#  '401': ['acq'],
#  '402': ['coffee'],
#  '404': ['earn'],
#  '405': ['earn'],
#  '406': ['earn'],
#  '407': ['earn'],
#  '408': ['acq'],
#  '409': ['earn'],
#  '410': ['earn'],
#  '411': ['interest', 'money-fx'],
#  '416': ['reserves'],
#  '417': ['oat', 'grain'],
#  '418': ['acq'],
#  '420': ['earn'],
#  '422': ['earn'],
#  '423': ['earn'],
#  '424': ['acq'],
#  '425': ['dlr', 'wheat', 'grain'],
#  '435': ['earn'],
#  '436': ['acq'],
#  '438': ['earn'],
#  '439': ['earn'],
#  '440': ['acq'],
#  '441': ['acq'],
#  '442': ['acq'],
#  '443': ['l-cattle', 'livestock'],
#  '444': ['retail'],
#  '447': ['acq'],
#  '448': ['platinum', 'acq', 'gold'],
#  '449': ['earn'],
#  '450': ['ipi'],
#  '455': ['earn'],
#  '456': ['earn'],
#  '459': ['crude'],
#  '461': ['earn'],
#  '464': ['earn'],
#  '466': ['earn'],
#  '467': ['acq'],
#  '470': ['earn'],
#  '473': ['acq', 'earn'],
#  '474': ['acq'],
#  '475': ['interest', 'money-fx'],
#  '478': ['acq'],
#  '480': ['earn'],
#  '483': ['earn'],
#  '484': ['earn'],
#  '486': ['oilseed'],
#  '488': ['silver', 'gold'],
#  '489': ['crude'],
#  '490': ['earn'],
#  '494': ['earn'],
#  '496': ['acq'],
#  '497': ['acq'],
#  '498': ['acq'],
#  '501': ['barley', 'wheat', 'corn', 'grain'],
#  '502': ['crude'],
#  '504': ['acq'],
#  '505': ['acq'],
#  '506': ['earn'],
#  '508': ['earn'],
#  '509': ['earn'],
#  '511': ['crude'],
#  '512': ['earn'],
#  '513': ['earn'],
#  '514': ['earn'],
#  '516': ['corn', 'grain'],
#  '517': ['earn'],
#  '518': ['ship'],
#  '519': ['interest', 'money-fx'],
#  '521': ['earn'],
#  '522': ['interest', 'money-fx'],
#  '524': ['earn'],
#  '525': ['iron-steel'],
#  '528': ['earn'],
#  '529': ['earn'],
#  '530': ['earn'],
#  '531': ['earn'],
#  '532': ['acq'],
#  '533': ['earn'],
#  '534': ['earn'],
#  '535': ['earn'],
#  '536': ['earn'],
#  '538': ['earn'],
#  '539': ['earn'],
#  '541': ['earn'],
#  '543': ['crude'],
#  '544': ['nat-gas'],
#  '545': ['acq'],
#  '546': ['earn'],
#  '547': ['acq'],
#  '548': ['earn'],
#  '550': ['acq'],
#  '551': ['acq'],
#  '552': ['earn'],
#  '553': ['acq'],
#  '554': ['earn'],
#  '555': ['earn'],
#  '557': ['earn'],
#  '558': ['acq'],
#  '559': ['acq'],
#  '560': ['earn'],
#  '562': ['coffee'],
#  '677': ['ship'],
#  '679': ['acq'],
#  '680': ['earn'],
#  '682': ['acq'],
#  '684': ['sugar'],
#  '685': ['rubber'],
#  '686': ['earn'],
#  '687': ['earn'],
#  '688': ['tin'],
#  '689': ['earn'],
#  '690': ['earn'],
#  '691': ['earn'],
#  '692': ['earn'],
#  '693': ['earn'],
#  '694': ['corn', 'wheat', 'soybean', 'grain', 'oilseed'],
#  '695': ['earn'],
#  '696': ['earn'],
#  '697': ['gold'],
#  '698': ['earn'],
#  '699': ['earn'],
#  '700': ['earn'],
#  '701': ['earn'],
#  '702': ['earn'],
#  '703': ['acq'],
#  '704': ['crude'],
#  '706': ['acq'],
#  '707': ['earn'],
#  '708': ['nat-gas', 'crude'],
#  '709': ['acq'],
#  '712': ['acq'],
#  '714': ['acq'],
#  '715': ['earn'],
#  '718': ['trade'],
#  '722': ['earn'],
#  '724': ['acq'],
#  '725': ['acq'],
#  '728': ['earn'],
#  '730': ['acq', 'earn'],
#  '731': ['earn'],
#  '732': ['acq'],
#  '733': ['acq'],
#  '734': ['earn'],
#  '735': ['acq'],
#  '736': ['acq'],
#  '739': ['earn'],
#  '741': ['acq'],
#  '742': ['wheat', 'grain'],
#  '743': ['earn'],
#  '745': ['acq'],
#  '748': ['acq'],
#  '754': ['coffee'],
#  '756': ['earn'],
#  '757': ['acq'],
#  '758': ['earn'],
#  '762': ['acq'],
#  '764': ['acq'],
#  '767': ['acq'],
#  '768': ['acq'],
#  '773': ['earn'],
#  '774': ['earn'],
#  '776': ['earn'],
#  '778': ['earn'],
#  '780': ['earn'],
#  '781': ['earn'],
#  '783': ['earn'],
#  '787': ['acq'],
#  '791': ['crude'],
#  '793': ['copper'],
#  '797': ['acq'],
#  '798': ['hog', 'livestock'],
#  '800': ['copper'],
#  '811': ['earn'],
#  '816': ['copper'],
#  '817': ['earn'],
#  '818': ['earn'],
#  '820': ['acq'],
#  '828': ['earn'],
#  '829': ['gas', 'heat', 'propane'],
#  '830': ['money-supply'],
#  '833': ['soybean', 'oilseed', 'soy-oil', 'veg-oil'],
#  '834': ['heat'],
#  '835': ['crude'],
#  '836': ['acq'],
#  '837': ['earn'],
#  '839': ['money-supply'],
#  '840': ['acq'],
#  '842': ['coffee'],
#  '843': ['trade', 'gnp'],
#  '844': ['acq'],
#  '846': ['earn'],
#  '848': ['earn'],
#  '849': ['acq'],
#  '850': ['acq'],
#  '851': ['acq'],
#  '852': ['earn'],
#  '853': ['acq'],
#  '855': ['soybean', 'oilseed', 'corn', 'oat', 'grain'],
#  '856': ['wheat', 'grain'],
#  '857': ['ship'],
#  '859': ['earn'],
#  '861': ['earn'],
#  '865': ['earn'],
#  '866': ['earn'],
#  '867': ['jobs'],
#  '868': ['earn'],
#  '870': ['lei'],
#  '872': ['dlr', 'yen', 'money-fx'],
#  '873': ['crude'],
#  '874': ['wheat', 'grain'],
#  '875': ['coffee'],
#  '879': ['earn'],
#  '880': ['bop'],
#  '882': ['acq'],
#  '883': ['earn'],
#  '884': ['rubber'],
#  '885': ['palm-oil', 'veg-oil'],
#  '886': ['earn'],
#  '887': ['earn'],
#  '889': ['jobs'],
#  '890': ['bop'],
#  '894': ['trade'],
#  '895': ['jobs'],
#  '896': ['reserves'],
#  '897': ['bop'],
#  '899': ['earn'],
#  '900': ['interest'],
#  '901': ['interest'],
#  '903': ['money-fx'],
#  '904': ['acq'],
#  '908': ['tin'],
#  '913': ['interest', 'money-fx'],
#  '915': ['money-fx'],
#  '918': ['crude'],
#  '920': ['earn'],
#  '921': ['alum', 'earn'],
#  '922': ['earn'],
#  '924': ['trade'],
#  '925': ['trade'],
#  '926': ['money-fx', 'interest'],
#  '929': ['cpi'],
#  '930': ['crude'],
#  '932': ['acq'],
#  '934': ['corn', 'grain'],
#  '937': ['reserves'],
#  '938': ['alum', 'earn'],
#  '939': ['acq'],
#  '940': ['money-supply'],
#  '941': ['acq'],
#  '942': ['money-fx', 'interest'],
#  '943': ['interest', 'money-fx'],
#  '944': ['palm-oil', 'veg-oil'],
#  '945': ['crude'],
#  '949': ['earn'],
#  '952': ['crude'],
#  '953': ['interest', 'money-fx'],
#  '955': ['jobs'],
#  '958': ['earn'],
#  '960': ['acq'],
#  '963': ['acq'],
#  '968': ['earn'],
#  '969': ['ship'],
#  '971': ['earn'],
#  '972': ['lei'],
#  '974': ['lei'],
#  '976': ['earn'],
#  '977': ['coffee'],
#  '978': ['acq'],
#  '981': ['earn'],
#  '982': ['acq'],
#  '983': ['earn'],
#  '984': ['earn'],
#  '985': ['acq'],
#  '986': ['earn'],
#  '988': ['crude', 'earn'],
#  '991': ['trade'],
#  '995': ['earn'],
#  '998': ['earn'],
#  '999': ['interest', 'money-fx'],
#  '1000': ['acq'],
#  '1003': ['earn'],
#  '1007': ['earn'],
#  '1008': ['interest', 'money-fx'],
#  '1009': ['earn'],
#  '1010': ['earn'],
#  '1011': ['earn'],
#  '1013': ['earn'],
#  '1015': ['earn'],
#  '1016': ['earn'],
#  '1017': ['earn'],
#  '1019': ['earn'],
#  '1020': ['acq'],
#  '1022': ['trade'],
#  '1023': ['lei'],
#  '1024': ['earn'],
#  '1026': ['crude', 'coffee'],
#  '1029': ['acq'],
#  '1030': ['coffee'],
#  '1032': ['acq'],
#  '1033': ['earn'],
#  '1035': ['housing'],
#  '1036': ['housing'],
#  '1039': ['acq'],
#  '1040': ['jobs'],
#  '1044': ['earn'],
#  '1047': ['earn'],
#  '1049': ['gnp'],
#  '1050': ['bop'],
#  '1052': ['ship'],
#  '1057': ['wheat', 'grain'],
#  '1058': ['gnp'],
#  '1059': ['earn'],
#  '1063': ['earn'],
#  '1065': ['earn'],
#  '1066': ['earn'],
#  '1067': ['barley', 'wheat', 'grain'],
#  '1068': ['gnp'],
#  '1069': ['wheat', 'grain'],
#  '1070': ['earn'],
#  '1071': ['earn'],
#  '1072': ['gold'],
#  '1074': ['acq'],
#  '1076': ['acq'],
#  '1077': ['zinc'],
#  '1078': ['interest'],
#  '1079': ['ipi'],
#  '1080': ['earn'],
#  '1082': ['gold'],
#  '1084': ['earn'],
#  '1085': ['coffee'],
#  '1087': ['earn'],
#  '1088': ['money-fx'],
#  '1090': ['earn'],
#  '1091': ['earn'],
#  '1094': ['wheat', 'grain'],
#  '1096': ['earn'],
#  '1099': ['acq'],
#  '1100': ['bop'],
#  '1101': ['earn'],
#  '1102': ['gnp'],
#  '1103': ['acq'],
#  '1104': ['acq'],
#  '1105': ['earn'],
#  '1108': ['earn'],
#  '1109': ['earn'],
#  '1110': ['carcass', 'livestock', 'veg-oil'],
#  '1111': ['earn'],
#  '1112': ['interest', 'money-fx'],
#  '1117': ['earn'],
#  '1118': ['acq'],
#  '1120': ['interest'],
#  '1122': ['earn'],
#  '1123': ['acq'],
#  '1124': ['earn'],
#  '1125': ['interest'],
#  '1128': ['earn'],
#  '1131': ['sorghum', 'corn', 'grain'],
#  '1134': ['earn'],
#  '1135': ['earn'],
#  '1137': ['earn'],
#  '1138': ['earn'],
#  '1143': ['earn'],
#  '1147': ['cpi'],
#  '1148': ['copper'],
#  '1151': ['rapeseed', 'oilseed'],
#  '1152': ['earn'],
#  '1153': ['acq'],
#  '1154': ['interest', 'money-fx'],
#  '1156': ['iron-steel'],
#  '1157': ['earn'],
#  '1158': ['ipi'],
#  '1159': ['acq'],
#  '1160': ['earn'],
#  '1164': ['acq'],
#  '1167': ['earn'],
#  '1169': ['earn'],
#  '1170': ['earn'],
#  '1173': ['earn'],
#  '1174': ['reserves'],
#  '1176': ['earn'],
#  '1177': ['earn'],
#  '1178': ['earn'],
#  '1181': ['earn'],
#  '1182': ['earn'],
#  '1184': ['copper'],
#  '1185': ['wheat', 'grain'],
#  '1188': ['earn'],
#  '1191': ['earn'],
#  '1192': ['earn'],
#  '1193': ['earn'],
#  '1197': ['trade'],
#  '1198': ['earn'],
#  '1200': ['earn'],
#  '1201': ['trade'],
#  '1203': ['acq'],
#  '1205': ['earn'],
#  '1207': ['coffee'],
#  '1208': ['earn'],
#  '1209': ['acq'],
#  '1210': ['trade'],
#  '1211': ['veg-oil'],
#  '1212': ['coffee'],
#  '1213': ['acq'],
#  '1215': ['corn', 'grain', 'soy-meal', 'meal-feed'],
#  '1216': ['sugar'],
#  '1217': ['acq'],
#  '1220': ['acq'],
#  '1225': ['earn'],
#  '1226': ['trade'],
#  '1228': ['acq'],
#  '1229': ['earn'],
#  '1234': ['earn'],
#  '1238': ['acq'],
#  '1239': ['earn'],
#  '1243': ['acq'],
#  '1244': ['earn'],
#  '1245': ['earn'],
#  '1246': ['coffee'],
#  '1251': ['earn'],
#  '1252': ['earn'],
#  '1257': ['ship', 'wheat', 'grain'],
#  '1258': ['earn'],
#  '1260': ['earn'],
#  '1263': ['alum'],
#  '1264': ['earn'],
#  '1265': ['earn'],
#  '1268': ['corn', 'grain'],
#  '1269': ['earn'],
#  '1271': ['earn'],
#  '1272': ['gnp'],
#  '1273': ['corn', 'grain'],
#  '1276': ['acq'],
#  '1277': ['earn'],
#  '1280': ['acq'],
#  '1283': ['earn'],
#  '1284': ['earn'],
#  '1285': ['earn'],
#  '1287': ['earn'],
#  '1288': ['earn'],
#  '1291': ['acq'],
#  '1292': ['acq'],
#  '1293': ['earn'],
#  '1295': ['wheat', 'grain'],
#  '1298': ['earn'],
#  '1299': ['grain'],
#  '1300': ['alum'],
#  '1301': ['earn'],
#  '1303': ['acq'],
#  '1306': ['crude'],
#  '1308': ['money-supply'],
#  '1311': ['earn'],
#  '1312': ['coffee'],
#  '1313': ['earn'],
#  '1314': ['earn'],
#  '1315': ['earn'],
#  '1316': ['acq'],
#  '1317': ['earn'],
#  '1320': ['earn'],
#  '1322': ['earn'],
#  '1324': ['crude'],
#  '1326': ['earn'],
#  '1327': ['earn'],
#  '1328': ['earn'],
#  '1331': ['crude'],
#  '1332': ['alum'],
#  '1335': ['crude'],
#  '1339': ['earn'],
#  '1340': ['acq'],
#  '1341': ['earn'],
#  '1342': ['earn'],
#  '1343': ['crude'],
#  '1344': ['earn'],
#  '1345': ['earn'],
#  '1347': ['trade'],
#  '1350': ['orange'],
#  '1351': ['earn'],
#  '1354': ['acq'],
#  '1355': ['earn'],
#  '1356': ['trade'],
#  '1359': ['earn'],
#  '1360': ['earn'],
#  '1361': ['orange'],
#  '1363': ['earn'],
#  '1364': ['earn'],
#  '1366': ['earn'],
#  '1367': ['earn'],
#  '1369': ['sorghum', 'corn', 'grain'],
#  '1372': ['carcass', 'livestock'],
#  '1375': ['earn'],
#  '1377': ['wheat', 'grain'],
#  '1378': ['earn'],
#  '1379': ['earn'],
#  '1381': ['earn'],
#  '1382': ['earn'],
#  '1384': ['earn'],
#  '1385': ['corn', 'wheat'],
#  '1387': ['crude'],
#  '1388': ['wheat', 'grain'],
#  '1391': ['earn'],
#  '1393': ['carcass', 'livestock'],
#  '1394': ['soybean', 'oilseed'],
#  '1395': ['corn', 'grain'],
#  '1396': ['wheat', 'grain'],
#  '1398': ['carcass', 'livestock'],
#  '1399': ['corn', 'grain'],
#  '1404': ['earn'],
#  '1405': ['soybean', 'oilseed', 'oat', 'wheat', 'cotton', 'grain'],
#  '1406': ['grain'],
#  '1407': ['carcass'],
#  '1409': ['acq'],
#  '1412': ['acq'],
#  '1414': ['earn'],
#  '1420': ['earn'],
#  '1421': ['interest', 'money-fx'],
#  '1425': ['acq'],
#  '1427': ['interest'],
#  '1428': ['earn'],
#  '1429': ['acq'],
#  '1433': ['earn'],
#  '1434': ['earn'],
#  '1435': ['earn'],
#  '1436': ['sugar'],
#  '1438': ['earn'],
#  '1440': ['sugar'],
#  '1444': ['rubber'],
#  '1445': ['earn'],
#  '1446': ['earn'],
#  '1449': ['earn'],
#  '1452': ['earn'],
#  '1456': ['earn'],
#  '1457': ['money-fx'],
#  '1460': ['earn'],
#  '1461': ['earn'],
#  '1466': ['earn'],
#  '1467': ['earn'],
#  '1469': ['earn'],
#  '1471': ['earn'],
#  '1477': ['acq'],
#  '1478': ['trade'],
#  '1480': ['acq'],
#  '1483': ['earn'],
#  '1488': ['earn'],
#  '1492': ['earn'],
#  '1493': ['pet-chem'],
#  '1494': ['earn'],
#  '1496': ['earn'],
#  '1497': ['acq'],
#  '1498': ['earn'],
#  '1499': ['trade'],
#  '1500': ['acq'],
#  '1502': ['earn'],
#  '1503': ['interest', 'money-fx'],
#  '1506': ['acq'],
#  '1508': ['earn'],
#  '1512': ['acq'],
#  '1514': ['money-fx', 'dlr'],
#  '1519': ['sugar'],
#  '1520': ['gas'],
#  '1521': ['crude'],
#  '1524': ['earn'],
#  '1525': ['earn'],
#  '1526': ['earn'],
#  '1527': ['earn'],
#  '1528': ['earn'],
#  '1529': ['earn'],
#  '1532': ['earn'],
#  '1533': ['dlr', 'money-fx'],
#  '1535': ['rubber'],
#  '1536': ['earn'],
#  '1537': ['sugar'],
#  '1541': ['earn'],
#  '1543': ['earn'],
#  '1545': ['earn'],
#  '1546': ['earn'],
#  '1550': ['cpi'],
#  '1553': ['money-fx', 'interest'],
#  '1554': ['earn'],
#  '1555': ['earn'],
#  '1556': ['ship', 'crude'],
#  '1557': ['grain', 'carcass', 'livestock'],
#  '1560': ['interest', 'money-fx'],
#  '1562': ['acq'],
#  '1563': ['earn'],
#  '1564': ['earn'],
#  '1566': ['earn'],
#  '1567': ['earn'],
#  '1568': ['earn'],
#  '1569': ['earn'],
#  '1570': ['wheat', 'grain'],
#  '1571': ['earn'],
#  '1572': ['earn'],
#  '1575': ['earn'],
#  '1577': ['acq'],
#  '1579': ['coffee'],
#  '1581': ['acq'],
#  '1582': ['soybean', 'sunseed', 'oilseed', 'sorghum', 'corn', 'grain'],
#  '1584': ['acq'],
#  '1585': ['earn'],
#  '1586': ['earn'],
#  '1588': ['trade'],
#  '1590': ['rice', 'cotton', 'wheat', 'grain'],
#  '1598': ['sugar'],
#  '1601': ['acq'],
#  '1602': ['earn'],
#  '1606': ['acq'],
#  '1607': ['copper', 'gold'],
#  '1608': ['earn'],
#  '1610': ['earn'],
#  '1611': ['gnp', 'trade', 'bop'],
#  '1616': ['crude'],
#  '1619': ['nat-gas'],
#  '1620': ['earn'],
#  '1622': ['acq'],
#  '1623': ['grain'],
#  '1626': ['acq'],
#  '1628': ['acq'],
#  '1631': ['grain'],
#  '1633': ['earn'],
#  '1634': ['acq'],
#  '1638': ['earn'],
#  '1639': ['earn'],
#  '1640': ['wheat', 'grain'],
#  '1642': ['earn'],
#  '1643': ['earn'],
#  '1644': ['earn'],
#  '1648': ['earn'],
#  '1649': ['acq'],
#  '1650': ['earn'],
#  '1651': ['earn'],
#  '1652': ['corn', 'barley', 'grain'],
#  '1653': ['earn'],
#  '1655': ['earn'],
#  '1656': ['trade'],
#  '1657': ['earn'],
#  '1658': ['earn'],
#  '1659': ['acq'],
#  '1660': ['fuel', 'gas'],
#  '1661': ['crude', 'nat-gas'],
#  '1665': ['acq'],
#  '1666': ['acq'],
#  '1667': ['acq'],
#  '1673': ['acq'],
#  '1674': ['wheat', 'grain'],
#  '1675': ['trade'],
#  '1676': ['acq'],
#  '1677': ['earn'],
#  '1678': ['acq'],
#  '1679': ['acq'],
#  '1680': ['trade'],
#  '1681': ['cpi'],
#  '1682': ['earn'],
#  '1684': ['acq'],
#  '1686': ['crude'],
#  '1688': ['earn'],
#  '1689': ['earn'],
#  '1692': ['crude'],
#  '1693': ['acq'],
#  '1694': ['acq'],
#  '1696': ['earn'],
#  '1706': ['earn'],
#  '1708': ['earn'],
#  '1709': ['nat-gas', 'crude'],
#  '1711': ['crude'],
#  '1714': ['earn'],
#  '1715': ['coffee'],
#  '1716': ['earn'],
#  '1718': ['earn'],
#  '1719': ['acq'],
#  '1722': ['earn'],
#  '1723': ['ship'],
#  '1724': ['money-fx', 'interest'],
#  '1727': ['earn'],
#  '1729': ['acq'],
#  '1731': ['grain'],
#  '1732': ['earn'],
#  '1734': ['earn'],
#  '1735': ['acq'],
#  '1739': ['acq'],
#  '1740': ['acq'],
#  '1741': ['acq'],
#  '1747': ['earn'],
#  '1751': ['earn'],
#  '1752': ['earn'],
#  '1758': ['earn'],
#  '1759': ['earn'],
#  '1760': ['acq'],
#  '1761': ['orange'],
#  '1763': ['earn'],
#  '1764': ['earn'],
#  '1765': ['earn'],
#  '1767': ['earn'],
#  '1768': ['earn'],
#  '1769': ['earn'],
#  '1771': ['acq'],
#  '1772': ['trade', 'carcass', 'livestock'],
#  '1773': ['reserves'],
#  '1777': ['wheat', 'corn', 'grain'],
#  '1783': ['earn'],
#  '1785': ['sugar'],
#  '1787': ['acq'],
#  '1789': ['acq'],
#  '1790': ['acq'],
#  '1792': ['soybean', 'oilseed', 'wheat', 'grain'],
#  '1794': ['earn'],
#  '1797': ['earn'],
#  '1798': ['acq'],
#  '1799': ['crude'],
#  '1801': ['acq'],
#  '1803': ['earn'],
#  '1808': ['acq'],
#  '1809': ['trade'],
#  '1811': ['trade', 'money-fx'],
#  '1814': ['earn'],
#  '1815': ['sugar'],
#  '1816': ['earn'],
#  '1820': ['earn'],
#  '1824': ['earn'],
#  '1832': ['alum'],
#  '1835': ['acq'],
#  '1836': ['acq'],
#  '1837': ['earn'],
#  '1839': ['trade'],
#  '1842': ['coffee'],
#  '1843': ['sorghum', 'corn', 'grain'],
#  '1845': ['grain'],
#  '1846': ['earn'],
#  '1847': ['acq'],
#  '1848': ['veg-oil'],
#  '1849': ['earn'],
#  '1851': ['crude', 'gas'],
#  '1853': ['earn'],
#  '1855': ['acq'],
#  '1856': ['fuel', 'gas', 'crude'],
#  '1858': ['gnp'],
#  '1860': ['earn', 'acq'],
#  '1861': ['earn'],
#  '1862': ['acq'],
#  '1863': ['trade'],
#  '1871': ['trade'],
#  '1872': ['earn'],
#  '1873': ['earn'],
#  '1875': ['crude'],
#  '1877': ['earn'],
#  '1878': ['gas', 'crude'],
#  '1880': ['coffee'],
#  '1882': ['soybean', 'oilseed', 'rice', 'cotton', 'grain'],
#  '1885': ['reserves'],
#  '1886': ['acq'],
#  '1889': ['coffee'],
#  '1890': ['trade', 'bop'],
#  '1897': ['gold'],
#  '1898': ['money-supply'],
#  '1901': ['ship', 'wheat', 'grain'],
#  '1902': ['ship'],
#  '1904': ['crude', 'ship'],
#  '1907': ['wheat', 'grain'],
#  '1909': ['crude'],
#  '1910': ['coffee'],
#  '1912': ['money-supply'],
#  '1913': ['reserves'],
#  '1915': ['rice', 'grain'],
#  '1917': ['earn'],
#  '1918': ['gold'],
#  '1919': ['earn'],
#  '1920': ['acq'],
#  '1924': ['earn'],
#  '1926': ['yen', 'dlr', 'money-fx'],
#  '1929': ['tin'],
#  ...}

# %%
train_docs[2]
# Out:
# 'ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS\n  Argentine grain board figures show\n  crop registrations of grains, oilseeds and their products to\n  February 11, in thousands of tonnes, showing those for futurE\n  shipments month, 1986/87 total and 1985/86 total to February\n  12, 1986, in brackets:\n      Bread wheat prev 1,655.8, Feb 872.0, March 164.6, total\n  2,692.4 (4,161.0).\n      Maize Mar 48.0, total 48.0 (nil).\n      Sorghum nil (nil)\n      Oilseed export registrations were:\n      Sunflowerseed total 15.0 (7.9)\n      Soybean May 20.0, total 20.0 (nil)\n      The board also detailed export registrations for\n  subproducts, as follows,\n      SUBPRODUCTS\n      Wheat prev 39.9, Feb 48.7, March 13.2, Apr 10.0, total\n  111.8 (82.7) .\n      Linseed prev 34.8, Feb 32.9, Mar 6.8, Apr 6.3, total 80.8\n  (87.4).\n      Soybean prev 100.9, Feb 45.1, MAr nil, Apr nil, May 20.0,\n  total 166.1 (218.5).\n      Sunflowerseed prev 48.6, Feb 61.5, Mar 25.1, Apr 14.5,\n  total 149.8 (145.3).\n      Vegetable oil registrations were :         \n      Sunoil prev 37.4, Feb 107.3, Mar 24.5, Apr 3.2, May nil,\n  Jun 10.0, total 182.4 (117.6).                  \n      Linoil prev 15.9, Feb 23.6, Mar 20.4, Apr 2.0, total 61.8,\n  (76.1).                         \n      Soybean oil prev 3.7, Feb 21.1, Mar nil, Apr 2.0, May 9.0,\n  Jun 13.0, Jul 7.0, total 55.8 (33.7).        REUTER\n  \n\n'
