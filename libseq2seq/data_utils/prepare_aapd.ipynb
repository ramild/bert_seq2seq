# %%
import os
import numpy as np
from tqdm import tqdm

DATA_DIR = '../../datasets/AAPD'

# %%
def get_docs(filepath):
    doc = open(filepath, 'r', encoding='utf-8')
    docs = [text.strip() for text in doc.readlines()]
    return docs

def get_labels(filepath):
    label_doc = open(filepath, 'r', encoding='utf-8')
    labels = [label_line.strip().split()
              for label_line in label_doc.readlines()]
    return labels

# %%
train_docs = get_docs(os.path.join(DATA_DIR, 'text_train'))
valid_docs = get_docs(os.path.join(DATA_DIR, 'text_val'))
test_docs = get_docs(os.path.join(DATA_DIR, 'text_test'))

train_labels = get_labels(os.path.join(DATA_DIR, 'label_train'))
valid_labels = get_labels(os.path.join(DATA_DIR, 'label_val'))
test_labels = get_labels(os.path.join(DATA_DIR, 'label_test'))

# %%
(len(train_docs), len(valid_docs), len(test_docs),
 len(train_labels), len(valid_labels),  len(test_labels))
# Out:
# (53840, 1000, 1000, 53840, 1000, 1000)

# %%
labels_set = set()
for labels in train_labels:
    labels_set |= set(labels)
len(labels_set)
# Out:
# 54

# %%
label_names = np.array(list(labels_set))
label_to_index = dict(zip(label_names, np.arange(len(label_names))))

# %%
frequences = [0] * len(label_to_index)
for ind in range(len(train_labels)):
    for label_index in train_labels[ind]:
        frequences[label_to_index[label_index]] += 1
        
index_to_frequency_index = dict(zip(np.argsort(frequences)[::-1],
                                    np.arange(len(frequences))))
frequency_indexes = [index_to_frequency_index[label_to_index[label]]
                     for label in label_names]
label_to_index = dict(zip(label_names, frequency_indexes))
index_to_label = dict(zip(frequency_indexes, label_names))

labels_train = []
for labels in train_labels:
    labels_train.append(sorted(
        [label_to_index[label] for label in labels]))
    
labels_valid = []
for labels in valid_labels:
    labels_valid.append(sorted(
        [label_to_index[label] for label in labels]))
    
labels_test = []
for labels in test_labels:
    labels_test.append(sorted(
        [label_to_index[label] for label in labels]))

# %%
index_to_label_str = {str(index): label for index, label in index_to_label.items()}

# %%
import json
with open(os.path.join(DATA_DIR, 'index_to_label.json'), 'w') as outfile:
    json.dump(index_to_label_str, outfile)

# %%
import pandas as pd

# %%
df_train = pd.DataFrame({
    'text': train_docs,
    'labels': labels_train
})

df_valid = pd.DataFrame({
    'text': valid_docs,
    'labels': labels_valid
})

df_test = pd.DataFrame({
    'text': test_docs,
    'labels': labels_test
})

# %%
df_train
# Out:
#                                                     text             labels
# 0      the relation between pearson 's correlation co...           [20, 45]
# 1      the present work studies quantum and classical...         [0, 1, 22]
# 2      one of the most important tasks in image proce...           [15, 44]
# 3      frequency diverse \( fd \) radar waveforms are...         [0, 1, 44]
# 4      unsupervised word embeddings have been shown t...            [3, 14]
# 5      a discrete time wiener phase noise channel wit...             [0, 1]
# 6      in this paper , we consider a particular class...             [0, 1]
# 7      the gallager bound is well known in the area o...             [0, 1]
# 8      symmetric tensor operations arise in a wide va...           [32, 46]
# 9      in a basic related key attack against a block ...     [0, 1, 16, 22]
# 10     this work considers the smart repeater network...             [0, 1]
# 11     bike sharing systems are a means of smart tran...            [2, 26]
# 12     recently , different communities in computer s...           [11, 18]
# 13     consider a polynomial f in m variables and a f...             [0, 1]
# 14     due to the increasing heterogeneity and deploy...             [0, 1]
# 15     the cluster editing problem seeks a transforma...            [5, 12]
# 16     there is a vast supply of prior art that study...            [3, 35]
# 17     robotic systems must be able to quickly and ro...            [2, 34]
# 18     in this paper , we develop a new decoding algo...             [0, 1]
# 19     we study the problem of geometric optimization...         [0, 1, 11]
# 20     we consider the problem of soft decision fusio...         [0, 1, 11]
# 21     we consider the distributed source coding syst...             [0, 1]
# 22     important applications in robotic and sensor n...           [13, 18]
# 23     this paper resolves an open problem raised by ...            [5, 16]
# 24     we propose a framework for the decentralized c...           [18, 31]
# 25     this work started out with our accidental disc...           [11, 41]
# 26     our paper explores contribution patterns of cr...            [7, 10]
# 27     we consider a stationary and ergodic source p ...             [0, 1]
# 28     we show in this paper that , on the one hand ,...            [3, 20]
# 29     we consider information theoretic secret key a...         [0, 1, 16]
# ...                                                  ...                ...
# 53810  an algorithm which either finds an nonzero int...       [12, 49, 50]
# 53811  data mining techniques have been widely used t...           [23, 25]
# 53812  in this note we suggest that difficulties enco...            [3, 14]
# 53813  the advanced encryption standard \( aes \) is ...         [0, 1, 16]
# 53814  we describe algorithms for drawing media , sys...            [5, 28]
# 53815  the dominant approach for many nlp tasks are r...        [2, 14, 19]
# 53816  in this paper we introduce the two user asynch...             [0, 1]
# 53817  this paper presents an online reinforcement le...    [2, 13, 33, 44]
# 53818  let mathcal x be an n element set assume maths...          [0, 1, 9]
# 53819  in this paper , we address the problem of simu...       [13, 18, 31]
# 53820  complex networks have been characterised by th...        [7, 10, 52]
# 53821  this paper presents a concurrent learning base...           [13, 18]
# 53822  we study the extent to which contact less and ...           [30, 48]
# 53823  despite considerable number of studies on risk...            [2, 23]
# 53824  concurrent constraint programming \( ccp \) is...            [8, 24]
# 53825  the concept of generalized domination unifies ...            [6, 12]
# 53826  the optimal diversity multiplexing delay trade...             [0, 1]
# 53827  we consider a wiretap channel with an eavesdro...             [0, 1]
# 53828  parsing expression grammars \( pegs \) are a f...           [24, 35]
# 53829  we study unique recovery of cosparse signals f...         [0, 1, 32]
# 53830  in this paper are briefly outlined the motivat...        [8, 24, 25]
# 53831  the design of modulation schemes for the physi...             [0, 1]
# 53832  in many mathematical models of physical phenom...           [18, 29]
# 53833  we introduce a high probability framework for ...         [0, 1, 21]
# 53834  characterizing human mobility patterns is esse...        [7, 10, 23]
# 53835  this volume contains papers presented at wlpe ...        [8, 24, 26]
# 53836  in this paper we analyse belief propagation ov...  [0, 1, 3, 10, 43]
# 53837  inference problems in graphical models are oft...             [2, 4]
# 53838  the classical emd algorithm has been used exte...       [29, 32, 51]
# 53839  in this paper we argue for a paradigmatic shif...           [14, 22]
#
# [53840 rows x 2 columns]

# %%
df_train.to_csv(os.path.join(DATA_DIR, 'train.csv'),
                encoding='utf-8', index=0)
df_valid.to_csv(os.path.join(DATA_DIR, 'valid.csv'),
                encoding='utf-8', index=0)
df_test.to_csv(os.path.join(DATA_DIR, 'test.csv'),
               encoding='utf-8', index=0)

# %%
doc_lengths = [len(train_docs[i].split()) for i in range(len(train_docs))]
np.mean(doc_lengths), np.std(doc_lengths)
# Out:
# (163.4520059435364, 67.62282864261516)
